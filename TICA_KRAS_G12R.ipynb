# %% [markdown]
# KRAS MUTANT

# %%
import mdtraj as md
import pyemma
import matplotlib.pyplot as plt
import numpy as np
# ✅ Patch NumPy deprecated alias
if not hasattr(np, 'bool'):
    np.bool = bool
# Out:
# /tmp/ipykernel_245063/1368747323.py:6: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, 'bool'):

# %%
import pyemma
import mdtraj
import types

# ✅ Monkey patch mdtraj to add the missing version attribute
if not hasattr(mdtraj, 'version'):
    mdtraj.version = types.SimpleNamespace(version='1.9.9')
elif not hasattr(mdtraj.version, 'version'):
    mdtraj.version.version = '1.9.9'

# %%
feat = pyemma.coordinates.featurizer(r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/7599/md_7599.gro')
feat.add_backbone_torsions(cossin=True) 

data1 = pyemma.coordinates.load([r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/7599/md_7599.xtc'], features=feat)

tica = pyemma.coordinates.tica(data1, lag=10, dim=2, kinetic_map=True)
tica_output = tica.get_output()[0]


np.savetxt('tica_output_data1.txt', tica_output, fmt='%.6f', delimiter='\t')


plt.scatter(tica_output[:,0], tica_output[:,1], c=range(len(tica_output)), cmap='viridis', s=5)
plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('TICA Projection of MD Trajectory')
plt.colorbar(label='Frame index')
plt.show()
# Out:
# /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py:235: PyEMMA_DeprecationWarning: Call to deprecated function "tica". Called from /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py line 235. Use deeptime.decomposition.TICA instead.
#   return caller(func, *(extras + args), **kw)

# %% [markdown]
# DATA2

# %%
feat = pyemma.coordinates.featurizer(r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/C109/md_C109.gro')
feat.add_backbone_torsions(cossin=True) 

data2 = pyemma.coordinates.load([r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/C109/md_C109.xtc'], features=feat)

tica = pyemma.coordinates.tica(data2, lag=10, dim=2, kinetic_map=True)
tica_output = tica.get_output()[0]


np.savetxt('tica_output_data2.txt', tica_output, fmt='%.6f', delimiter='\t')


plt.scatter(tica_output[:,0], tica_output[:,1], c=range(len(tica_output)), cmap='viridis', s=5)
plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('TICA Projection of MD Trajectory')
plt.colorbar(label='Frame index')
plt.show()
# Out:
# /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py:235: PyEMMA_DeprecationWarning: Call to deprecated function "tica". Called from /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py line 235. Use deeptime.decomposition.TICA instead.
#   return caller(func, *(extras + args), **kw)

# %% [markdown]
# DATA3

# %%
feat = pyemma.coordinates.featurizer(r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/K284/md_K284.gro')
feat.add_backbone_torsions(cossin=True) 

data3 = pyemma.coordinates.load([r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/K284/md_K284.xtc'], features=feat)

tica = pyemma.coordinates.tica(data3, lag=10, dim=2, kinetic_map=True)
tica_output = tica.get_output()[0]


np.savetxt('tica_output_data3.txt', tica_output, fmt='%.6f', delimiter='\t')


plt.scatter(tica_output[:,0], tica_output[:,1], c=range(len(tica_output)), cmap='viridis', s=5)
plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('TICA Projection of MD Trajectory')
plt.colorbar(label='Frame index')
plt.show()
# Out:
# /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py:235: PyEMMA_DeprecationWarning: Call to deprecated function "tica". Called from /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py line 235. Use deeptime.decomposition.TICA instead.
#   return caller(func, *(extras + args), **kw)

# %% [markdown]
# DATA4

# %%
feat = pyemma.coordinates.featurizer(r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/L150/md_L150.gro')
feat.add_backbone_torsions(cossin=True) 

data4 = pyemma.coordinates.load([r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/L150/md_L150.xtc'], features=feat)

tica = pyemma.coordinates.tica(data4, lag=10, dim=2, kinetic_map=True)
tica_output = tica.get_output()[0]


np.savetxt('tica_output_data4.txt', tica_output, fmt='%.6f', delimiter='\t')


plt.scatter(tica_output[:,0], tica_output[:,1], c=range(len(tica_output)), cmap='viridis', s=5)
plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('TICA Projection of MD Trajectory')
plt.colorbar(label='Frame index')
plt.show()
# Out:
# /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py:235: PyEMMA_DeprecationWarning: Call to deprecated function "tica". Called from /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py line 235. Use deeptime.decomposition.TICA instead.
#   return caller(func, *(extras + args), **kw)

# %% [markdown]
# DATA5

# %%
feat = pyemma.coordinates.featurizer(r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/NSC374/md_NSC374.gro')
feat.add_backbone_torsions(cossin=True) 

data5 = pyemma.coordinates.load([r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/NSC374/md_NSC374.xtc'], features=feat)

tica = pyemma.coordinates.tica(data5, lag=10, dim=2, kinetic_map=True)
tica_output = tica.get_output()[0]


np.savetxt('tica_output_data5.txt', tica_output, fmt='%.6f', delimiter='\t')


plt.scatter(tica_output[:,0], tica_output[:,1], c=range(len(tica_output)), cmap='viridis', s=5)
plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('TICA Projection of MD Trajectory')
plt.colorbar(label='Frame index')
plt.show()
# Out:
# /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py:235: PyEMMA_DeprecationWarning: Call to deprecated function "tica". Called from /home/swati/anaconda3/envs/scaffold_hunter_env/lib/python3.9/site-packages/decorator.py line 235. Use deeptime.decomposition.TICA instead.
#   return caller(func, *(extras + args), **kw)

# %% [markdown]
# MERGED

# %%
import numpy as np
import matplotlib.pyplot as plt

files = [ r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/tica_output_data1.txt',
    r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/tica_output_data2.txt',
    r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/tica_output_data3.txt',
    r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/tica_output_data4.txt',
    r'/media/swati/ADHVIK/TLIC_7599/revision_KRAS_TLICA/G12R/tica_output_data5.txt']

compound_labels = ['7599-1863', 'C109-0694', 'K284-1836', 'L150-1140', 'NSC374037']
colormaps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis']

plt.figure(figsize=(8,6))

for idx, file in enumerate(files):
    data = np.loadtxt(file)
    # color by frame index per compound, with different colormaps
    plt.scatter(data[:,0], data[:,1], c=range(len(data)), cmap=colormaps[idx], s=5, label=compound_labels[idx])

plt.xlabel('TICA 1')
plt.ylabel('TICA 2')
plt.title('Merged TICA Projection ')
plt.legend()
plt.colorbar(label='Frame index (per compound)')
plt.show()
